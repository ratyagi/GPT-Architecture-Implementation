# %% [markdown]
# [![Github](https://img.shields.io/github/stars/labmlai/annotated_deep_learning_paper_implementations?style=social)](https://github.com/labmlai/annotated_deep_learning_paper_implementations)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/labmlai/annotated_deep_learning_paper_implementations/blob/master/labml_nn/transformers/gpt/experiment.ipynb)
#
# ## Training a model with GPT architecture
#
# This is an experiment training Tiny Shakespeare dataset with GPT architecture model.

# %% [markdown]
# Install the `labml-nn` package

# %%
# !pip install labml-nn
# Out:
# Collecting labml-nn
#   Downloading labml_nn-0.4.137-py3-none-any.whl.metadata (9.2 kB)
# Collecting labml==0.4.168 (from labml-nn)
#   Downloading labml-0.4.168-py3-none-any.whl.metadata (7.5 kB)
# Collecting labml-helpers==0.4.89 (from labml-nn)
#   Downloading labml_helpers-0.4.89-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from labml-nn) (2.5.1+cu121)
# Collecting torchtext (from labml-nn)
#   Downloading torchtext-0.18.0-cp310-cp310-manylinux1_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from labml-nn) (0.20.1+cu121)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from labml-nn) (0.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from labml-nn) (1.26.4)
# Collecting fairscale (from labml-nn)
#   Downloading fairscale-0.4.13.tar.gz (266 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 6.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gitpython in /usr/local/lib/python3.10/dist-packages (from labml==0.4.168->labml-nn) (3.1.43)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from labml==0.4.168->labml-nn) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->labml-nn) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->labml-nn) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->labml-nn) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->labml-nn) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->labml-nn) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->labml-nn) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->labml-nn) (1.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext->labml-nn) (4.66.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext->labml-nn) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->labml-nn) (11.0.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython->labml==0.4.168->labml-nn) (4.0.11)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->labml-nn) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext->labml-nn) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext->labml-nn) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext->labml-nn) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext->labml-nn) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython->labml==0.4.168->labml-nn) (5.0.1)
# Downloading labml_nn-0.4.137-py3-none-any.whl (443 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.9/443.9 kB 12.2 MB/s eta 0:00:00
# Downloading labml-0.4.168-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 8.7 MB/s eta 0:00:00
# Downloading labml_helpers-0.4.89-py3-none-any.whl (24 kB)
# Downloading torchtext-0.18.0-cp310-cp310-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 53.5 MB/s eta 0:00:00
# Building wheels for collected packages: fairscale
#   Building wheel for fairscale (pyproject.toml) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.13-py3-none-any.whl size=332106 sha256=496a8d84cbe2e6dd5c016f51d8b134374d41b10d4051c2f1727ba2b7f1685f7d
#   Stored in directory: /root/.cache/pip/wheels/78/a4/c0/fb0a7ef03cff161611c3fa40c6cf898f76e58ec421b88e8cb3
# Successfully built fairscale
# Installing collected packages: torchtext, labml, fairscale, labml-helpers, labml-nn
# Successfully installed fairscale-0.4.13 labml-0.4.168 labml-helpers-0.4.89 labml-nn-0.4.137 torchtext-0.18.0

# %% [markdown]
# Imports

# %%
import torch
import torch.nn as nn

from labml import experiment
from labml.configs import option
from labml_helpers.module import Module
from labml_nn.transformers.gpt import Configs

# %% [markdown]
# Create an experiment

# %%
experiment.create(name="gpt")

# %% [markdown]
# Initialize [GPT configurations](https://nn.labml.ai/transformers/gpt/)

# %%
conf = Configs()

# %% [markdown]
# Set experiment configurations and assign a configurations dictionary to override configurations

# %%
experiment.configs(conf, {
    # Use character level tokenizer
    'tokenizer': 'character',
    # Prompt separator is blank
    'prompt_separator': '',
    # Starting prompt for sampling
    'prompt': 'It is ',
    # Use Tiny Shakespeare dataset
    'text': 'tiny_shakespeare',

    # Use a context size of $128$
    'seq_len': 128,
    # Train for $32$ epochs
    'epochs': 32,
    # Batch size $128$
    'batch_size': 128,
    # Switch between training and validation for $10$ times
    # per epoch
    'inner_iterations': 10,

    # Transformer configurations
    'transformer.d_model': 512,
    'transformer.ffn.d_ff': 2048,
    'transformer.n_heads': 8,
    'transformer.n_layers': 6
})
# Out:
# <pre style="overflow-x: scroll;"></pre>

# %% [markdown]
# Set PyTorch models for loading and saving

# %%
experiment.add_pytorch_models({'model': conf.model})
# Out:
# <pre style="overflow-x: scroll;">Prepare model...
#   Prepare transformer...
#     Prepare n_tokens...
#       Prepare text...
#         Prepare tokenizer<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	4.39ms</span>
#         Download<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	724.81ms</span>
#         Load data<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	4.08ms</span>
#         Tokenize<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	32.71ms</span>
#         Build vocabulary<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	25.63ms</span>
#       Prepare text<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	806.82ms</span>
#     Prepare n_tokens<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	813.25ms</span>
#     Prepare ffn<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	2.01ms</span>
#   Prepare transformer<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	827.06ms</span>
#   Prepare transformer.encoder...
#     Prepare transformer.encoder_layer...
#       Prepare transformer.encoder_attn<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	39.55ms</span>
#       Prepare ffn.ffn...
#         Prepare ffn.activation<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	4.53ms</span>
#       Prepare ffn.ffn<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	36.79ms</span>
#     Prepare transformer.encoder_layer<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	118.88ms</span>
#   Prepare transformer.encoder<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	185.71ms</span>
#   Prepare transformer.src_embed<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	83.90ms</span>
#   Prepare transformer.generator<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	2.82ms</span>
#   Prepare device.device...
#     Prepare device.device_info<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	62.79ms</span>
#   Prepare device.device<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	66.57ms</span>
# Prepare model<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	1,478.50ms</span>
# </pre>

# %% [markdown]
# Start the experiment and run the training loop.

# %%
# Start the experiment
with experiment.start():
    conf.run()
# Out:
# <pre style="overflow-x: scroll;"><strong><span style="color: #DDB62B">No labml server url specified. Please start a labml server and specify the URL. Docs: https://github.com/labmlai/labml/tree/master/app</span></strong>
#
# <strong><span style="text-decoration: underline">gpt</span></strong>: <span style="color: #208FFB">09372d3aa56c11ef80aa0242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# Initialize...
#   Prepare mode<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	4.76ms</span>
# Initialize<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	98.18ms</span>
# Prepare validator...
#   Prepare valid_loader<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	165.72ms</span>
# Prepare validator<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	341.78ms</span>
# Prepare trainer...
#   Prepare train_loader<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	361.32ms</span>
# Prepare trainer<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	429.42ms</span>
# Prepare training_loop...
#   Prepare loop_count<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	51.27ms</span>
# Prepare training_loop<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	361.94ms</span>
# <span style="color: #C5C1B4">It is </span><strong>3</strong><strong>'</strong><strong>-</strong><strong>T</strong><strong>s</strong><strong>w</strong><strong>'</strong><strong>R</strong><strong>t</strong><strong>'</strong><strong>s</strong><strong>Y</strong><strong>Y</strong><strong>e</strong><strong>'</strong><strong>&</strong><strong>s</strong><strong>Y</strong><strong>Y</strong><strong>F</strong><strong>G</strong><strong>z</strong><strong>:</strong><strong>s</strong><strong>Y</strong>
# <strong><span style="color: #DDB62B">       0:  </span></strong>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">    819ms  </span>Train:<span style="color: #C5C1B4">  ...</span><span style="color: #208FFB">  0ms  </span>  <span style="color: #208FFB">819ms</span><span style="color: #D160C4">  0:00m/  0:00m  </span>
# Prepare optimizer<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	138.86ms</span>
# Prepare optimizer.optimizer...
#   Prepare optimizer.weight_decay_obj<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	3.84ms</span>
# Prepare optimizer.optimizer<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	4,511.08ms</span>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong>r</strong><strong>e</strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>a</strong><strong>t</strong><strong>h</strong><strong>a</strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong>
# <strong><span style="color: #DDB62B">1,003,776:  </span></strong>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">    323ms  </span>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  44,391ms  </span>Valid:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 1,542ms  </span> loss.train: <span style="color: #C5C1B4"> 2.38816</span> accuracy.train: <span style="color: #C5C1B4">0.248990</span> loss.valid: <span style="color: #C5C1B4"> 2.37164</span> accuracy.valid: <span style="color: #C5C1B4">0.267455</span>  <span style="color: #208FFB">54,841ms</span><span style="color: #D160C4">  0:00m/  0:28m  </span>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</
